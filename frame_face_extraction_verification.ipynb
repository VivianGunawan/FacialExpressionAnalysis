# %%
import cv2
import numpy as np
import pandas as pd
from PIL import Image
import glob
import matplotlib.pyplot as plt
from scipy.spatial import distance
from math import inf
import face_recognition as fr

# %%
import time
import os

# %%
# technique from the following sources
# https://sefiks.com/2020/08/25/deep-face-detection-with-opencv-in-python/
# https://sefiks.com/2018/08/06/deep-face-recognition-with-keras/
#load the face detector for opencv
detector = cv2.dnn.readNetFromCaffe("deploy.prototxt",
                                    "res10_300x300_ssd_iter_140000.caffemodel")

# make a dictionary containing the reference images for the candidates
reference = {}
numbers = list(range(0,10))
for image in glob.glob("reference_images/*.jpg"):
    candidate = image.replace("reference_images/", '')
    candidate = candidate.replace(".jpg", '')
    for number in numbers:
        candidate = candidate.replace(str(number), '')
    real_face = cv2.imread(image)
    reference[candidate] = real_face   

start = time.time()    
vid_number = 1
# iterate through the videos
for video in glob.glob("./video_2020/VideoClips/*.mp4"):
    
    # extract the video path
    video_path = video.replace("./video_2020/VideoClips/", '')
    video_path = video_path.replace(".mp4", '')
    
#     if any(video_path in directory for directory in existing):
#         continue
    
    # make two new directories to store the face image and the face image in gray
    os.mkdir(f"./299_verified_2020/{video_path}")
    os.mkdir(f"./299_verified_2020_gray/{video_path}")
    
    # extract the candidate name
    candidate = video.replace("./video_2020/VideoClips/", '')
    candidate = candidate.replace(".mp4", '')
    candidate = candidate.replace("_", "")
    
    for number in numbers:
        candidate = candidate.replace(str(number), '')
    
    # read the video
    video = cv2.VideoCapture(video)

    # count the number of frames read
    count = 0
    success = True

    # use a loop to get each frame from the video
    while success:

        # get each frame, detect whether a frame was successfully extracted
        success, image = video.read()

        if success == False:
            break
            
        base_img = image.copy()

        original_size = base_img.shape

        target_size = (300, 300)
        image = cv2.resize(image, target_size)

        aspect_ratio_x = (original_size[1] / target_size[1])
        aspect_ratio_y = (original_size[0] / target_size[0])

        imageBlob = cv2.dnn.blobFromImage(image = image)
        detector.setInput(imageBlob)
        detections = detector.forward()

        # get a dataframe of all the faces detected in teh image
        column_labels = ["img_id", "is_face", "confidence", "left", "top", "right", "bottom"]
        detections_df = pd.DataFrame(detections[0][0], columns = column_labels)
        detections_df = detections_df[detections_df['is_face'] == 1]
        detections_df = detections_df[detections_df['confidence']>=0.60]
        detections_df['left'] = (detections_df['left'] * 300).astype(int)
        detections_df['bottom'] = (detections_df['bottom'] * 300).astype(int)
        detections_df['right'] = (detections_df['right'] * 300).astype(int)
        detections_df['top'] = (detections_df['top'] * 300).astype(int)
        
        if len(detections_df) == 0:
            continue

        shortest = inf
        closest = 0

        # go through each detected face and compare to the reference image
        # store the most similar face
        for i, instance in detections_df.iterrows():
            confidence_score = str(round(100*instance["confidence"], 2))+"%"
            left = int(instance["left"])
            right = int(instance["right"])
            bottom = int(instance["bottom"])
            top = int(instance["top"])

            detected_face = base_img[int(top*aspect_ratio_y):int(bottom*aspect_ratio_y), int(left*aspect_ratio_x):int(right*aspect_ratio_x)]

            try:
                final_image = cv2.resize(detected_face, (224, 224))
            except:
                continue
                
            final_image = cv2.cvtColor(final_image, cv2.COLOR_BGR2GRAY)

            reference_image = reference[candidate]

            reference_image = cv2.cvtColor(reference_image, cv2.COLOR_BGR2GRAY)

            cos_dist = distance.cosine(final_image.ravel(), reference_image.ravel())

            if cos_dist < shortest:
                shortest = cos_dist
                closest = i
            
        # save the confirmed face to the relevant directory
        confirmed_face = detections_df.loc[i]

        left = int(confirmed_face["left"])
        right = int(instance["right"])
        bottom = int(confirmed_face["bottom"])
        top = int(confirmed_face["top"])

        confirmed_face = base_img[int(top*aspect_ratio_y):int(bottom*aspect_ratio_y), int(left*aspect_ratio_x):int(right*aspect_ratio_x)]

        confirmed_face = cv2.resize(confirmed_face, (299, 299))

        cv2.imwrite(f"299_verified_2020/{video_path}/frame{count}.jpg", confirmed_face)

        count += 1
        
    current_time = time.time()
    if vid_number % 10 == 0:
        duration = current_time - start
        print(f"{vid_number} videos processed")
        print(f"Time elapsed: {duration}")
        time_per_video = duration/vid_number
        remaining_videos = 1506 - vid_number
        estimated_time_remaining = time_per_video*remaining_videos
        print(f"Estimated time remaining: {estimated_time_remaining}")

    vid_number += 1
# Out:
# 10 videos processed
# Time elapsed: 27.73526906967163
# Estimated time remaining: 4149.196252822876
# 20 videos processed
# Time elapsed: 53.19948482513428
# Estimated time remaining: 3952.721722507477
# 30 videos processed
# Time elapsed: 88.75356364250183
# Estimated time remaining: 4366.67533121109
# 40 videos processed
# Time elapsed: 112.9350483417511
# Estimated time remaining: 4139.069521725178
# 50 videos processed
# Time elapsed: 147.7690281867981
# Estimated time remaining: 4303.03410079956
# 60 videos processed
# Time elapsed: 188.28458642959595
# Estimated time remaining: 4537.658532953263
# 70 videos processed
# Time elapsed: 201.52779459953308
# Estimated time remaining: 4134.198757784707
# 80 videos processed
# Time elapsed: 231.3229479789734
# Estimated time remaining: 4123.331547725201
# 90 videos processed
# Time elapsed: 255.9573531150818
# Estimated time remaining: 4027.0623556772866
# 100 videos processed
# Time elapsed: 287.94150495529175
# Estimated time remaining: 4048.457559671402
# 110 videos processed
# Time elapsed: 323.93964648246765
# Estimated time remaining: 4111.088604450226
# 120 videos processed
# Time elapsed: 337.87138080596924
# Estimated time remaining: 3902.4144483089444
# 130 videos processed
# Time elapsed: 356.493367433548
# Estimated time remaining: 3773.345181450477
# 140 videos processed
# Time elapsed: 388.38700675964355
# Estimated time remaining: 3789.5475088119506
# 150 videos processed
# Time elapsed: 410.0571599006653
# Estimated time remaining: 3706.9167255020143
# 160 videos processed
# Time elapsed: 437.33454513549805
# Estimated time remaining: 3679.076860952377
# 170 videos processed
# Time elapsed: 467.86216592788696
# Estimated time remaining: 3676.8461981156292
# 180 videos processed
# Time elapsed: 493.8712475299835
# Estimated time remaining: 3638.184856804212
# 190 videos processed
# Time elapsed: 519.5429315567017
# Estimated time remaining: 3598.5184101506284
# 200 videos processed
# Time elapsed: 544.6542382240295
# Estimated time remaining: 3556.592175602913
# 210 videos processed
# Time elapsed: 573.3500397205353
# Estimated time remaining: 3538.3888165610174
# 220 videos processed
# Time elapsed: 595.1432626247406
# Estimated time remaining: 3478.882889706438
# 230 videos processed
# Time elapsed: 612.9778816699982
# Estimated time remaining: 3400.6946826561634
# 240 videos processed
# Time elapsed: 635.5033769607544
# Estimated time remaining: 3352.2803134679793
# 250 videos processed
# Time elapsed: 672.511780500412
# Estimated time remaining: 3378.69918523407
# 260 videos processed
# Time elapsed: 689.1962940692902
# Estimated time remaining: 3302.840701578214
# 270 videos processed
# Time elapsed: 707.9533455371857
# Estimated time remaining: 3240.8530929035614
# 280 videos processed
# Time elapsed: 726.3512542247772
# Estimated time remaining: 3180.3808488556315
# 290 videos processed
# Time elapsed: 750.8751108646393
# Estimated time remaining: 3148.4970165910395
# 300 videos processed
# Time elapsed: 774.5073776245117
# Estimated time remaining: 3113.519658050537
# 310 videos processed
# Time elapsed: 809.0743899345398
# Estimated time remaining: 3121.461194715192
# 320 videos processed
# Time elapsed: 829.84916472435
# Estimated time remaining: 3075.6284667596224
# 330 videos processed
# Time elapsed: 865.9589405059814
# Estimated time remaining: 3085.962769803134
# 340 videos processed
# Time elapsed: 884.8582429885864
# Estimated time remaining: 3034.5432686020345
# 350 videos processed
# Time elapsed: 910.8887219429016
# Estimated time remaining: 3008.5353216171266
# 360 videos processed
# Time elapsed: 936.7312841415405
# Estimated time remaining: 2981.927921183904
# 370 videos processed
# Time elapsed: 971.1604907512665
# Estimated time remaining: 2981.7251824146992
# 380 videos processed
# Time elapsed: 984.29368019104
# Estimated time remaining: 2916.617589197661
# 390 videos processed
# Time elapsed: 1009.5382168292999
# Estimated time remaining: 2888.8324358499967
# 400 videos processed
# Time elapsed: 1026.2655000686646
# Estimated time remaining: 2837.6241076898577
# 410 videos processed
# Time elapsed: 1054.597004890442
# Estimated time remaining: 2819.1178472193274
# 420 videos processed
# Time elapsed: 1078.3934490680695
# Estimated time remaining: 2788.4173468760077
# 430 videos processed
# Time elapsed: 1103.674816608429
# Estimated time remaining: 2761.7537271410924
# 440 videos processed
# Time elapsed: 1124.9508109092712
# Estimated time remaining: 2725.4490100665525
# 450 videos processed
# Time elapsed: 1145.3347074985504
# Estimated time remaining: 2687.718780263265
# 460 videos processed
# Time elapsed: 1164.771535396576
# Estimated time remaining: 2648.589187010475
# 470 videos processed
# Time elapsed: 1204.5606291294098
# Estimated time remaining: 2655.1591739958903
# 480 videos processed
# Time elapsed: 1227.218384027481
# Estimated time remaining: 2623.1792958587407
# 490 videos processed
# Time elapsed: 1252.204619884491
# Estimated time remaining: 2596.407946536006
# 500 videos processed
# Time elapsed: 1267.7914922237396
# Estimated time remaining: 2550.7964823541643
# 510 videos processed
# Time elapsed: 1298.4913446903229
# Estimated time remaining: 2535.8772143363954
# 520 videos processed
# Time elapsed: 1312.808434009552
# Estimated time remaining: 2489.28676141042
# 530 videos processed
# Time elapsed: 1345.9766232967377
# Estimated time remaining: 2478.628649693615
# 540 videos processed
# Time elapsed: 1366.0911617279053
# Estimated time remaining: 2443.785300424364
# 550 videos processed
# Time elapsed: 1390.9763271808624
# Estimated time remaining: 2417.769761427099
# 560 videos processed
# Time elapsed: 1416.8759307861328
# Estimated time remaining: 2393.508268792289
# 570 videos processed
# Time elapsed: 1433.3496043682098
# Estimated time remaining: 2353.7109292783234
# 580 videos processed
# Time elapsed: 1458.0223624706268
# Estimated time remaining: 2327.808116634139
# 590 videos processed
# Time elapsed: 1484.5993330478668
# Estimated time remaining: 2304.9033713082135
# 600 videos processed
# Time elapsed: 1512.8311126232147
# Estimated time remaining: 2284.3749800610544
# 610 videos processed
# Time elapsed: 1534.524885892868
# Estimated time remaining: 2253.99065206559
# 620 videos processed
# Time elapsed: 1557.1257300376892
# Estimated time remaining: 2225.182898086117
# 630 videos processed
# Time elapsed: 1584.0232059955597
# Estimated time remaining: 2202.5465530985875
# 640 videos processed
# Time elapsed: 1608.2865183353424
# Estimated time remaining: 2176.2126951225105
# 650 videos processed
# Time elapsed: 1627.2746930122375
# Estimated time remaining: 2142.995595720731
# 660 videos processed
# Time elapsed: 1675.3062076568604
# Estimated time remaining: 2147.4379570874303
# 670 videos processed
# Time elapsed: 1695.0714054107666
# Estimated time remaining: 2115.0443207811954
# 680 videos processed
# Time elapsed: 1717.884422302246
# Estimated time remaining: 2086.7243129730227
# 690 videos processed
# Time elapsed: 1740.3559560775757
# Estimated time remaining: 2058.160087187394
# 700 videos processed
# Time elapsed: 1762.8891553878784
# Estimated time remaining: 2029.8409417751857
# 710 videos processed
# Time elapsed: 1794.6688573360443
# Estimated time remaining: 2012.0512823091426
# 720 videos processed
# Time elapsed: 1822.1652610301971
# Estimated time remaining: 1989.1970766246318
# 730 videos processed
# Time elapsed: 1850.4687287807465
# Estimated time remaining: 1967.073607580629
# 740 videos processed
# Time elapsed: 1874.0952126979828
# Estimated time remaining: 1939.9418012522362
# 750 videos processed
# Time elapsed: 1896.611342906952
# Estimated time remaining: 1911.7842336502076
# 760 videos processed
# Time elapsed: 1917.184594631195
# Estimated time remaining: 1881.8680363090416
# 770 videos processed
# Time elapsed: 1933.1984498500824
# Estimated time remaining: 1847.8364403761827
# 780 videos processed
# Time elapsed: 1957.7583301067352
# Estimated time remaining: 1822.2212149454997
# 790 videos processed
# Time elapsed: 1981.3122282028198
# Estimated time remaining: 1795.720956193948
# 800 videos processed
# Time elapsed: 2004.2129831314087
# Estimated time remaining: 1768.7179576134681
# 810 videos processed
# Time elapsed: 2032.1509101390839
# Estimated time remaining: 1746.1444857491388
# 820 videos processed
# Time elapsed: 2054.3760328292847
# Estimated time remaining: 1718.6609250254749
# 830 videos processed
# Time elapsed: 2075.7754340171814
# Estimated time remaining: 1690.6315583079695
# 840 videos processed
# Time elapsed: 2102.9917771816254
# Estimated time remaining: 1667.3720519082885
# 850 videos processed
# Time elapsed: 2125.553472518921
# Estimated time remaining: 1640.427150555779
# 860 videos processed
# Time elapsed: 2144.671493768692
# Estimated time remaining: 1610.9974243890406
# 870 videos processed
# Time elapsed: 2177.402193069458
# Estimated time remaining: 1591.7560859680175
# 880 videos processed
# Time elapsed: 2212.6960673332214
# Estimated time remaining: 1574.031520625678
# 890 videos processed
# Time elapsed: 2242.107758998871
# Estimated time remaining: 1551.8408758913533
# 900 videos processed
# Time elapsed: 2269.3735723495483
# Estimated time remaining: 1528.0448720486959
# 910 videos processed
# Time elapsed: 2296.6383821964264
# Estimated time remaining: 1504.1719514165604
# 920 videos processed
# Time elapsed: 2321.3988797664642
# Estimated time remaining: 1478.6301560251609
# 930 videos processed
# Time elapsed: 2348.7913298606873
# Estimated time remaining: 1454.7352752685547
# 940 videos processed
# Time elapsed: 2372.461413860321
# Estimated time remaining: 1428.5246385584485
# 950 videos processed
# Time elapsed: 2395.661288499832
# Estimated time remaining: 1402.092290953586
# 960 videos processed
# Time elapsed: 2423.4301483631134
# Estimated time remaining: 1378.3258968815207
# 970 videos processed
# Time elapsed: 2453.161076784134
# Estimated time remaining: 1355.5611723260781
# 980 videos processed
# Time elapsed: 2473.390573978424
# Estimated time remaining: 1327.5545325639296
# 990 videos processed
# Time elapsed: 2501.1693003177643
# Estimated time remaining: 1303.6397565292589
# 1000 videos processed
# Time elapsed: 2522.3634226322174
# Estimated time remaining: 1276.315891851902
# 1010 videos processed
# Time elapsed: 2538.180028438568
# Estimated time remaining: 1246.4725684213167
# 1020 videos processed
# Time elapsed: 2553.6610107421875
# Estimated time remaining: 1216.744363941866
# 1030 videos processed
# Time elapsed: 2580.98353099823
# Estimated time remaining: 1192.7652046166577
# 1040 videos processed
# Time elapsed: 2608.7814931869507
# Estimated time remaining: 1168.9347844472297
# 1050 videos processed
# Time elapsed: 2623.5948622226715
# Estimated time remaining: 1139.389768736703
# 1060 videos processed
# Time elapsed: 2647.5053758621216
# Estimated time remaining: 1113.9503751268928
# 1070 videos processed
# Time elapsed: 2677.9164912700653
# Estimated time remaining: 1091.1884020502323
# 1080 videos processed
# Time elapsed: 2689.176442861557
# Estimated time remaining: 1060.7307080176142
# 1090 videos processed
# Time elapsed: 2722.610573530197
# Estimated time remaining: 1039.088072099598
# 1100 videos processed
# Time elapsed: 2747.5712416172028
# Estimated time remaining: 1014.1035673605311
# 1110 videos processed
# Time elapsed: 2783.466259241104
# Estimated time remaining: 993.0203951887182
# 1120 videos processed
# Time elapsed: 2801.1024689674377
# Estimated time remaining: 965.3799580548491
# 1130 videos processed
# Time elapsed: 2826.8512625694275
# Estimated time remaining: 940.6159953328361
# 1140 videos processed
# Time elapsed: 2848.1480877399445
# Estimated time remaining: 914.4054386954558
# 1150 videos processed
# Time elapsed: 2873.972495317459
# Estimated time remaining: 889.6819202895787
# 1160 videos processed
# Time elapsed: 2900.866043806076
# Estimated time remaining: 865.2583199628468
# 1170 videos processed
# Time elapsed: 2918.9503581523895
# Estimated time remaining: 838.2626669565836
# 1180 videos processed
# Time elapsed: 2946.9971096515656
# Estimated time remaining: 814.1703879206868
# 1190 videos processed
# Time elapsed: 2961.0182540416718
# Estimated time remaining: 786.2872002329145
# 1200 videos processed
# Time elapsed: 3009.0703840255737
# Estimated time remaining: 767.3129479265212
# 1210 videos processed
# Time elapsed: 3039.7877173423767
# Estimated time remaining: 743.6174911845814
# 1220 videos processed
# Time elapsed: 3064.266995191574
# Estimated time remaining: 718.3445578891723
# 1230 videos processed
# Time elapsed: 3094.9146633148193
# Estimated time remaining: 694.4686561584473
# 1240 videos processed
# Time elapsed: 3109.2768375873566
# Estimated time remaining: 666.9900312889007
# 1250 videos processed
# Time elapsed: 3124.8133895397186
# Estimated time remaining: 639.9617821777343
# 1260 videos processed
# Time elapsed: 3158.661443710327
# Estimated time remaining: 616.6910437720162
# 1270 videos processed
# Time elapsed: 3182.4437696933746
# Estimated time remaining: 591.3832516910524
# 1280 videos processed
# Time elapsed: 3212.0793199539185
# Estimated time remaining: 567.1327549293637
# 1290 videos processed
# Time elapsed: 3236.5091919898987
# Estimated time remaining: 541.9271205192389
# 1300 videos processed
# Time elapsed: 3262.433557987213
# Estimated time remaining: 516.9702407272046
# 1310 videos processed
# Time elapsed: 3288.0879521369934
# Estimated time remaining: 491.95819741897
# 1320 videos processed
# Time elapsed: 3313.351400613785
# Estimated time remaining: 466.8813337228515
# 1330 videos processed
# Time elapsed: 3335.3968753814697
# Estimated time remaining: 441.37582711814935
# 1340 videos processed
# Time elapsed: 3380.6693625450134
# Estimated time remaining: 418.79933894214344
# 1350 videos processed
# Time elapsed: 3405.7231912612915
# Estimated time remaining: 393.5502354346381
# 1360 videos processed
# Time elapsed: 3435.5468921661377
# Estimated time remaining: 368.8160634237177
# 1370 videos processed
# Time elapsed: 3468.833500146866
# Estimated time remaining: 344.35135475910494
# 1380 videos processed
# Time elapsed: 3489.8859095573425
# Estimated time remaining: 318.6417569595834
# 1390 videos processed
# Time elapsed: 3511.7498495578766
# Estimated time remaining: 293.0668939199379
# 1400 videos processed
# Time elapsed: 3533.884788751602
# Estimated time remaining: 267.56556257690704
# 1410 videos processed
# Time elapsed: 3561.175543785095
# Estimated time remaining: 242.46301574707033
# 1420 videos processed
# Time elapsed: 3591.4197804927826
# Estimated time remaining: 217.50852191716854
# 1430 videos processed
# Time elapsed: 3614.300456762314
# Estimated time remaining: 192.08869560415096
# 1440 videos processed
# Time elapsed: 3626.9856176376343
# Estimated time remaining: 166.23684080839158
# 1450 videos processed
# Time elapsed: 3652.4448702335358
# Estimated time remaining: 141.05993981591587
# 1460 videos processed
# Time elapsed: 3666.719437122345
# Estimated time remaining: 115.5267767860465
# 1470 videos processed
# Time elapsed: 3706.0938925743103
# Estimated time remaining: 90.7614830834525
# 1480 videos processed
# Time elapsed: 3725.1468830108643
# Estimated time remaining: 65.44176956640707
# 1490 videos processed
# Time elapsed: 3748.8773095607758
# Estimated time remaining: 40.2564006395788
# 1500 videos processed
# Time elapsed: 3764.4308755397797
# Estimated time remaining: 15.05772350215912
